# %% [markdown]
# # Calculator

# %% [markdown]
# # I made this as a minor Project .I used JUPYTER NOTEBOOK for made this .

# %%
from tkinter import *
def click(event):
    global scvalue
    text = event.widget.cget("text")
    if text == "=":
        if scvalue.get().isdigit():
            value = int(scvalue.get())
        else:
            try:
                value = eval(screen.get())

            except Exception as e:
                print(e)
                value ="Error"

        scvalue.set(value)
        screen.update()

    elif text == "C":
        scvalue.set("")
        screen.update()

    else:
        scvalue.set(scvalue.get()  + text)
        scvalue.update()


root = Tk()
root.geometry("644x900")
root.title("Calculator")

scvalue = StringVar()
scvalue.set("")
screen = Entry(root, textvar = scvalue , font = "lucida 40 bold")
screen.pack(fill = X , ipadx = 8 , pady = 10 , padx = 10)

f = Frame(root , bg = "grey")
b = Button(f, text = "9" ,  font = "lucida 30 bold")
b.pack(side=LEFT , padx= 18 , pady = 5)
b.bind("<Button - 1>" , click )

b = Button(f, text = "8", font = "lucida 30 bold")
b.pack(side=LEFT, padx= 18 , pady = 5)
b.bind("<Button - 1>" , click )

b = Button(f, text = "7", font = "lucida 30 bold")
b.pack(side=LEFT  , padx= 18 , pady = 5)
b.bind("<Button - 1>" , click )
f.pack()

f = Frame(root , bg = "grey")
b = Button(f, text = "6",  font = "lucida 30 bold")
b.pack(side=LEFT , padx= 18 , pady = 5)
b.bind("<Button - 1>" , click )

b = Button(f, text = "5", font = "lucida 30 bold")
b.pack(side=LEFT, padx= 18 , pady = 5)
b.bind("<Button - 1>" , click )

b = Button(f, text = "4", font = "lucida 30 bold")
b.pack(side=LEFT  , padx= 18 , pady = 5)
b.bind("<Button - 1>" , click )
f.pack()

f = Frame(root , bg = "grey")
b = Button(f, text = "3",  font = "lucida 30 bold")
b.pack(side=LEFT , padx= 18 , pady = 5)
b.bind("<Button - 1>" , click )

b = Button(f, text = "2", font = "lucida 30 bold")
b.pack(side=LEFT, padx= 18 , pady = 5)
b.bind("<Button - 1>" , click )

b = Button(f, text = "1", font = "lucida 30 bold")
b.pack(side=LEFT  , padx= 18 , pady = 5)
b.bind("<Button - 1>" , click )
f.pack()

f = Frame(root , bg = "grey")
b = Button(f, text = "0",padx = 8 , pady = 9, font = "lucida 30 bold")
b.pack(side=LEFT , padx= 18 , pady = 5)
b.bind("<Button - 1>" , click )

b = Button(f, text = "-",  font = "lucida 30 bold")
b.pack(side=LEFT, padx= 18 , pady = 5)
b.bind("<Button - 1>" , click )

b = Button(f, text = "*", font = "lucida 30 bold")
b.pack(side=LEFT  , padx= 18 , pady = 5)
b.bind("<Button - 1>" , click )
f.pack()

f = Frame(root , bg = "grey")
b = Button(f, text = "/",  font = "lucida 30 bold")
b.pack(side=LEFT , padx= 15 , pady = 5)
b.bind("<Button - 1>" , click )

b = Button(f, text = "%", font = "lucida 30 bold")
b.pack(side=LEFT, padx= 20 , pady = 9)
b.bind("<Button - 1>" , click )

b = Button(f, text = "=", font = "lucida 30 bold")
b.pack(side=LEFT  , padx= 18 , pady = 5)
b.bind("<Button - 1>" , click )
f.pack()
f = Frame(root , bg = "grey")
b = Button(f, text = "C",  font = "lucida 30 bold")
b.pack(side=LEFT , padx= 15 , pady = 5)
b.bind("<Button - 1>" , click )

b = Button(f, text = "8", font = "lucida 30 bold")
b.pack(side=LEFT, padx= 18 , pady = 5)
b.bind("<Button - 1>" , click )

b = Button(f, text = "7", font = "lucida 30 bold")
b.pack(side=LEFT  , padx= 18 , pady = 5)
b.bind("<Button - 1>" , click )
f.pack()
root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\pradeeep\anaconda3\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-4-03bc748965e8>", line 25, in click
#     scvalue.update()
# AttributeError: 'StringVar' object has no attribute 'update'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\pradeeep\anaconda3\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-4-03bc748965e8>", line 25, in click
#     scvalue.update()
# AttributeError: 'StringVar' object has no attribute 'update'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\pradeeep\anaconda3\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-4-03bc748965e8>", line 25, in click
#     scvalue.update()
# AttributeError: 'StringVar' object has no attribute 'update'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\pradeeep\anaconda3\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-4-03bc748965e8>", line 25, in click
#     scvalue.update()
# AttributeError: 'StringVar' object has no attribute 'update'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\pradeeep\anaconda3\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-4-03bc748965e8>", line 25, in click
#     scvalue.update()
# AttributeError: 'StringVar' object has no attribute 'update'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\pradeeep\anaconda3\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-4-03bc748965e8>", line 25, in click
#     scvalue.update()
# AttributeError: 'StringVar' object has no attribute 'update'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\pradeeep\anaconda3\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-4-03bc748965e8>", line 25, in click
#     scvalue.update()
# AttributeError: 'StringVar' object has no attribute 'update'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\pradeeep\anaconda3\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-4-03bc748965e8>", line 25, in click
#     scvalue.update()
# AttributeError: 'StringVar' object has no attribute 'update'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\pradeeep\anaconda3\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-4-03bc748965e8>", line 25, in click
#     scvalue.update()
# AttributeError: 'StringVar' object has no attribute 'update'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\pradeeep\anaconda3\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-4-03bc748965e8>", line 25, in click
#     scvalue.update()
# AttributeError: 'StringVar' object has no attribute 'update'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\pradeeep\anaconda3\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-4-03bc748965e8>", line 25, in click
#     scvalue.update()
# AttributeError: 'StringVar' object has no attribute 'update'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\pradeeep\anaconda3\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-4-03bc748965e8>", line 25, in click
#     scvalue.update()
# AttributeError: 'StringVar' object has no attribute 'update'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\pradeeep\anaconda3\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-4-03bc748965e8>", line 25, in click
#     scvalue.update()
# AttributeError: 'StringVar' object has no attribute 'update'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\pradeeep\anaconda3\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-4-03bc748965e8>", line 25, in click
#     scvalue.update()
# AttributeError: 'StringVar' object has no attribute 'update'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\pradeeep\anaconda3\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-4-03bc748965e8>", line 25, in click
#     scvalue.update()
# AttributeError: 'StringVar' object has no attribute 'update'
# invalid syntax (<string>, line 1)
